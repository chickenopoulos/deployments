# %%
import pandas as pd

# %%
pd.read_parquet('./data/binance_futures_basis_coinglass.parquet')
# Out:
#                time  open_basis  close_basis  open_change  close_change  \
# 0     1688169600000      0.0387       0.0402        11.79         12.30
# 1     1688256000000      0.0402       0.0141        12.30          4.33
# 2     1688342400000      0.0141       0.0231         4.32          7.20
# 3     1688428800000      0.0231       0.0338         7.20         10.41
# 4     1688515200000      0.0339       0.0538        10.42         16.41
# ...             ...         ...          ...          ...           ...
# 2995  1774137600000      0.0715       0.0507         1.49          1.04
# 2996  1774224000000      0.0507       0.0474         1.04          1.02
# 2997  1774310400000      0.0479       0.0436         1.03          0.94
# 2998  1774396800000      0.0427       0.0470         0.92          1.02
# 2999  1774483200000      0.0475       0.0500         1.03          1.03
#
#                       datetime    asset
# 0    2023-07-01 00:00:00+00:00  BTCUSDT
# ...
